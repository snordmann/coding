# %%
import tensorflow as tf
import numpy as np

# %%
#set hyperparameters
max_len = 12
step = 3
num_units = 128
learning_rate = 0.001
batch_size = 50
epoch = 60
temperature = 0.5

# %%
def read_data(file_name):
    '''
     open and read text file
    '''
    text = open(file_name, 'r').read()
    return text.lower()

def featurize(text):
    '''
     featurize the text to train and target dataset
    '''
    unique_chars = list(set(text))
    len_unique_chars = len(unique_chars)

    input_chars = []
    output_char = []

    for i in range(0, len(text) - max_len, step):
        input_chars.append(text[i:i+max_len])
        output_char.append(text[i+max_len])

    train_data = np.zeros((len(input_chars), max_len, len_unique_chars))
    target_data = np.zeros((len(input_chars), len_unique_chars))

    for i , each in enumerate(input_chars):
        for j, char in enumerate(each):
            train_data[i, j, unique_chars.index(char)] = 1
        target_data[i, unique_chars.index(output_char[i])] = 1
    return train_data, target_data, unique_chars, len_unique_chars

# %%
def rnn(x, weight, bias, len_unique_chars):
    '''
     define rnn cell and prediction
    '''
    x = tf.transpose(x, [1, 0, 2])
    x = tf.reshape(x, [-1, len_unique_chars])
    x = tf.split(x, max_len, 0)

    cell = tf.contrib.rnn.BasicLSTMCell(num_units, forget_bias=1.0)
    outputs, states = tf.contrib.rnn.static_rnn(cell, x, dtype=tf.float32)
    prediction = tf.matmul(outputs[-1], weight) + bias
    return prediction

# %%
def sample(predicted):
    '''
     helper function to sample an index from a probability array
    '''
    exp_predicted = np.exp(predicted/temperature)
    predicted = exp_predicted / np.sum(exp_predicted)
    probabilities = np.random.multinomial(1, predicted, 1)
    return probabilities

# %%
def run(train_data, target_data, unique_chars, len_unique_chars):
    '''
     main run function
    '''
    x = tf.placeholder("float", [None, max_len, len_unique_chars])
    y = tf.placeholder("float", [None, len_unique_chars])
    weight = tf.Variable(tf.random_normal([num_units, len_unique_chars]))
    bias = tf.Variable(tf.random_normal([len_unique_chars]))

    prediction = rnn(x, weight, bias, len_unique_chars)
    softmax = tf.nn.softmax_cross_entropy_with_logits(logits=prediction, labels=y)
    cost = tf.reduce_mean(softmax)
    optimizer = tf.train.RMSPropOptimizer(learning_rate=learning_rate).minimize(cost)

    init_op = tf.global_variables_initializer()
    sess = tf.Session()
    sess.run(init_op)

    num_batches = int(len(train_data)/batch_size)

    for i in range(epoch):
        print("----------- Epoch {0}/{1} -----------".format(i+1, epoch))
        count = 0
        for _ in range(num_batches):
            train_batch, target_batch = train_data[count:count+batch_size], target_data[count:count+batch_size]
            count += batch_size
            sess.run([optimizer] ,feed_dict={x:train_batch, y:target_batch})

        #get on of training set as seed
        seed = train_batch[:1:]
    

        #to print the seed 40 characters
        seed_chars = ''
        for each in seed[0]:
                seed_chars += unique_chars[np.where(each == max(each))[0][0]]
        print("Seed:", seed_chars)

        #predict next 1000 characters
        for i in range(1000):
            if i > 0:
                remove_fist_char = seed[:,1:,:]
                seed = np.append(remove_fist_char, np.reshape(probabilities, [1, 1, len_unique_chars]), axis=1)
            predicted = sess.run([prediction], feed_dict = {x:seed})
            predicted = np.asarray(predicted[0]).astype('float64')[0]
            probabilities = sample(predicted)
            predicted_chars = unique_chars[np.argmax(probabilities)]
            seed_chars += predicted_chars
        print('Result:', seed_chars)
    sess.close()

# %%
#get data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
text = read_data('nietzsche.txt')
train_data, target_data, unique_chars, len_unique_chars = featurize(text)
run(train_data, target_data, unique_chars, len_unique_chars)
# Out:
# ----------- Epoch 1/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# by mess shall we can and to speak the sall me the dong with may would readon, the hadd with the fairs, a made be not love of the moons fair the foround the dear can the the ford deniness preases to may be heart; and most me to the sweet to the onded and that should be not the bease shall
# in the pare,
# the fafes time, that would me prince in the comest the mong then wear man the mone well the priace there the counsers, and stall the conned; and for the bease morn a change her sence; for are is the light with a preadent the sent.
#
# boyet:
# many heart the wand.
#
# boyet:
# of she love of the pray of the man.
#
# boyet:
# not is, and you ad been to contain.
#
# boyet:
# in the privess your saye of should be fair for bearule the be orther.
#
# rosaline:
# a concess, we armadoned; so are bearion.
#
# princess:
# what the may bid of the prayse be would in the more are and as a prince of mans and engling dimaniess of the countare the leave the man.
#
# clenonine:
# the know they sine.
#
# biron:
# not proveles be the more.
#
# broke:
# ----------- Epoch 2/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# by the fair the trice; the trume,
# to the king and the princes?
#
# boyet:
# singer herce,
# the peentle the love in the right and with the parting man i confers than, and her with the course bearus as such and heart in hours, and moth moon.
#
# dumain:
# so not peen them to master, is the meass, and in shoulds the reasons.
#
# fordinal:
# a made theme.
#
# boyet:
# they say, by as the hours.
#
# resaline:
# what, house the heart as in the sentations the moon.
#
# rosaline:
# i will not a sente
# that them the with the maniest fall fair prayent the their princest not the day,
# and this is the greating of thee.
#
# matare:
# we will prease the fair and malk the tange the descress. be the confessine so to the wame, the fair worth.
#
# barin:
# i would see the not be hearted speed consent me so not be my moon of stirnus.
#
# for this effect, we are and at the dear with the heart with the warrance is the tongues,
# we wis not his in the name and moth; i have be hand ears of the word and the man of the praces, you spitted the towar, you will
# ----------- Epoch 3/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but i do is no more to the fair loves,
# and with the neight with a man is tongue than say i have a sence.
#
# massen:
# and they leave his sing and presenty.
#
# boyet:
# we not fair stome the honours, your word speaks you the deed the earth and not a man is that such son the harmed in the lawful fallows, be to this speaks by monsof the present,
# the came is their bearted monster,
# with the face of theme, and love my bearth peese say the eyes, i may not singer the courter for my love of the prest there are your fear, and they shouth is a lawful the soldier me then the confined in the present, that have maids be with the tongue of your are me wors and the present.
#
# boyet:
# sir, say the near, and he be sence her fall with a man every they of the after tray pray the most the train.
#
# rosaline:
# but they the morning made we perfore,
# and work the contray the bear thou did but this so presents,
# the confect and so more than the great prives a conferance the measers to one i have donea the trume, the content,
# ----------- Epoch 4/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but good meass and the death, and a man come by love of the prince and proves the great all thing that they may much they all the lady, do it is a bohe, fare they love and son a presence to our presence, what was the conterned than so long as the fair had we will on the sender man is present.
#
# costard:
# and they the entertion her man.
#
# anneseron:
# so for not the thing to me.
#
# boyet:
# and i will be bear the ears, and then were the wit is the old in the worn, the moon.
#
# rosaline:
# then we being such of the state,
# we must the worst be not to may as i am worth we shall be but for my please the like on of call and so a reader a man is good master than i pray you, and we will press the one to my love,
# i am as you do send to means the most perfection, on the cold send the man men the peace that the prisonce the three than with the hourself were senting meass and contracuted, and so love one the grace may be love me for that worthy wit of the prince with yourselves, then are the presence.
#
# boyet:
# n
# ----------- Epoch 5/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# by harm:
# sir, i would a servised.
#
# mailado:
# i will not see the cume.
#
# boyet:
# the counse and man than hold beauty of the please the beys the trume,
# to present the tawry,
# to be herstle?
#
# princess:
# that shall be some me that speech and they are a such an praise the more than sing them, then, say thou art at that then to a serves had and bring thee.
#
# boyet:
# and i am a man of heartal solemncal.
#
# boyet:
# they see the heart do grace then thou thought and woo not pray the man of the line.
#
# boyet:
# a fair sone what in the moon writtor:
# i will take the hours.
#
# rosaline:
# i have in the stand three well for the worthy present the truth and content the covertealty prove that prides the bast the more of the wards the time fines.
#
# boyet:
# that she is not presence it of one the sword and sorrow, and i have send.
#
# princess:
# she shall not part the continity with the words, then he day the world of the bedt the storn the sension, to you master, the day the tender; he deed me the hands than the sorrows and son
# ----------- Epoch 6/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# by a man is the new work cannot the news and be so put your word,
# the morn
# with the for me and that they will be play the feecels me than for what, and then, and the peace,
# and then lady.
#
# boyet:
# tell me the provese, is the boy the heart and the worst they would the poor be safeth the more a man be sentess and with the soor master, to may and love one the players to the feart of the wits the angleness, the beast the and wear the dead, and good lady: and the worst, and i will have it is the canders an old feirest thou grace the worse;
# which the stars to such vile pride and prove that absent by the world is a time and for the thanes and the news to can and strange and men, he doth man i will the present the lady, for me, and not do the fair and the moon,
# and i am such and to have the breath in the change the sight of the poese.
#
# dumain:
# prove a discredit in the bedure of longer, therefore provest and stay, and be so must do you send it with her that fair and man than here.
#
# third me, they
# ----------- Epoch 7/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be with offend the time with for the wind.
#
# macourer:
# how long i have speech demetrius wit the heaven, and i will great soul content of the beart than my liegel.
#
# rosaline:
# when thou art the are the day be should be stronger, and not the day of the princess the lovers for this provesters a beard; the sund the ward
# have weeps and the fear.
#
# biron:
# the letters, he is not a deliver me with the feech to paver say the speech and with the pask of the concount
# to be truth the shame the boy and we will i may prove the blood,
# and with the words and they says we play to speaken to the field amptites and write of heart,
# and the near the hogoss the present to a maident the hourselong so lose he would that say the softing than the fair repuied the course, under the love, and that love, see the measure by the sweet her offer to me witch.
#
# dumain:
# a speak it were the day were and the study.
#
# boyet:
# a fair super than a lovers than her herce to the man we keeps a poor art and prove grace men that was mo
# ----------- Epoch 8/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# by heart, and we than an in the father do much been of our faces the manshaloned with his loves of the offended a king of the boy,
# to the way, and i must contend, and then had a man prove the wife is an one of the ward and the reason.
#
# boyet:
# so is the time the peace.
#
# biron:
# and by the sleeps and some traingreats of the wife of the lady speak the sweet.
#
# boyet:
# not pria me to the fair hape of the present the play the canders and spirits of your brave
# than the hounds.
#
# dumain:
# i will for the lord.
#
# dumain:
# the beardas,
# and the day to the fault upon the worst that heart than her hath prove the wind the man is the care, and the manst as fair off and he led me
# to love i may deed to painter than our infirity.
#
# ferdinand:
# say to the wearter than in the talk of lord, than are the light for the pride
# and the wander, and shall he light have with all than so would to sole, sir, i will she have for my lord with thine eyes a finger of your beard, that is it is with the moon of the beast with a goo
# ----------- Epoch 9/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# both a bless
# to be so near the bearders, you contend, and they look and the lovers, we delame the motter on the one word here, contricle for the feeced from your fear, that is the stands to deed we every tumb them hang the length the hand, and the most created the head.
#
# maria:
# then, what they will not for your seeming than unto the pain is not be such and to may of the measure that shall you be.
#
# hermia:
# i am a sense in the thought the contraction than a word,
# that is the blood.
#
# patronca:
# which is the power,
# and with the wall.
#
# dumain:
# we will near the wasker in the man of the own than than and motter, and the pinmellow and with his praise it with his light
# and the night in the ear and heart present them, do you do what the travell in the words your light of this stunks every chance,
# and did be the man than this incersiraniar, and not his sore for been to you shall have gone to one and in mingled and sendent pain, for liege, as i will thou master
# than a spirits and the play the care o
# ----------- Epoch 10/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be gone me so with the lady, then, when she hath privection, and past man you the hands and the sun
# than the man with the battle stand and send thee to you are topgudiar sorrow of a vantain, that they have the man and save the boy.
#
# biron:
# shall i do not see the terrible speak,
# and present of the day and so, every most thunder than that with for a time the wind on the word with her house.
#
# boyet:
# then, let the moon of a pair as for the day, be will prove her wits and a very toward be some than of the fair face in the tower feel motter than the thing, i will have her man and the present their most bears that still his change to contract makes it is a confer
# that is the measure, by the day in the beauty and the shall be we are to be made the continded enterate.
#
# moth:
# and with the trunce with a gentle sir, and the dear is a man and ready present, and make it marria the cand
# to lie the and so love the eye are my speech and and the coll the sweet man in witched the men make been be the deed
# ----------- Epoch 11/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but so you ain, and in praise the cands to the time to make me that can privite in the parties measure yours to the foot the time with a scorn.
#
# boyet:
# sir, and so much be heaven's present
# the worthy word, and true it is means, see so spirits and be the fairer nor her beard this dance to say that we are present unto the most coiches with his change of it.
#
# boyet:
# the corder than to do is presents be more word,
# than lies were to play'd, the earl of the party break-fear to the gods and meet not us to you may be a love.
#
# longaville:
# and what shall not are to the contchat
# the many, the clear.
#
# rosaline:
# good lord love me at the boy the singer of more day and the tallent shall not as in the laid in fourt to still and that they are strange with offended did than a hard of the most nowe of my lady's letters are to the morth
# and here the wind!
#
# boyet:
# what shall prove the every tubul.
#
# boyet:
# what shall not a fear, i will pray the be look and a sight,
# that these world were a morn
# to make me as
# ----------- Epoch 12/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be men with the sentent them for a graces, for a thousand the name and to prove the time to the right, i think not all the one and heart present the earth shall be were to saint of the sending and troicul, and with her witet, and so do a motion, and a stands as i have in his side, and with his love, and one sensing in sectaning in the war, and they were the bearing make in the dead, and thou hast the god of the wares the name will be the natition for the mother's lord of the many thing well be so and present the sone and the beauty shall be hold
# have sure a man of the place we shall i do not stand the leave and by heaven, we must the bless the waster, the word,
# be would present dones and wort of death in the man, we come to that heart the dear be a bear out and an ang of the god is must of the boy to much the sweet, what is the kings of the face, they stand with the tongue to the leades.
#
# princess:
# what is the street of the word in the thing of heaven, i will be prayers prithee for a fe
# ----------- Epoch 13/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but their words than with the salk
# the man and call the hound these for his forgoting there the beast of the privile of their measure of the ladies by worth.
#
# princess:
# but, then from the wits of the part of the wind.
#
# longaville:
# some speak, the salister.
#
# rosaline:
# not fell the heavens of the first save to see the fair and his lady stand be contents me with a dumble the man at it lived not the captain, master than words, that the cause than her heart be have in the lovers, and so say and an eye, the perfect the leaves the distince and your sort be so with her honour fair we must be are that you shall be present the wise strange and shearing of the most pleasure with the fear,
# and they are the hands, sir, harks and son,
# and then desire the loved have confly wits of the man than the proclained by the ingenious tongues than mine own lies we would that in the man to say as i am read and four my partint,
# then wear that would contrar; i do then her doth off the fault of the shall be the bir
# ----------- Epoch 14/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be many day.
#
# fangardin:
# be with a for the charge that an englowe, he say that the that true, the heaven, and the fear.
#
# moth:
# hold father, and make one with a sendine
# of the travelly, to the first contrit the first more and all the way and the lady is not that for me, the word is a word of the boy,
# that we do be his durling the great bent to the child. then i shall play the princess of the devil, and there is a motter, let me with the armado:
# that we be thought in the concurt the word of contrave,
# and not moon men of her sake of the grace is the wars are mine enemy.
#
# boyet:
# seek the complexion, sir.
#
# forester:
# then the word and the man and fair princess, and then store than the monstent that sing the travelly.
#
# boyet:
# what we would so deer that will see his chineglass
# the continted and holds the contracled with passion.
#
# philowakin:
# a man for the man by his all the enemers.
#
# forester:
# so please your sword is more than all me then to , say then say.
#
# princess:
# so you may make his life,
# ----------- Epoch 15/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be as stater be passion in a contcies the thing in the love and delicated me to his bong the forsworn the time from the worse deceived on the day.
#
# ferdinand:
# this is a thousand privech?
#
# don adriano de and lead the can the praises
# to in a fair lady,
# i will say, but the moon and needs for my love.
#
# duniny:
# why, we will stay, sir, then day that should do me as in the fair loves the fair soul,
# the dearce of the mornable not and his country of service to the word of all the tongue.
#
# holofernes:
# and the sends the wear.
#
# man:
# not so sound, make a dear than the warlike the sensing with his leave the blood, which is the fair speech the musides they are too this show the three
# to your lovers, and in the lie, and to a fair loves, for his page.
#
# holofernes:
# we nestor is the town,
# and a tongues, in prisoner, i tell you the dark and was stand the house to dear many word, in the fair sweet grace the peace,
# that in love, this honour to passion and present of the send the monster, and in the world of
# ----------- Epoch 16/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but in fairest thou art the like one brangers than her wits with the worthy word of the beast to our fair sweet breath in his sound, and as it be too moons,
# and let thee with his instructard and there the coarce that of the end my contend.
#
# moth:
# you shall hear them so lieen ladies are a first, and then make the tenter have the bless the face and men not a books to the poetry that lies, for the world art more man's love too mind shall fair than the gentle with one the mother as i seems and mock the word of the side: make a man and feeding the name of the arms of the man of thought the wits of the loss' her tongues shall not see the wind.
#
# boyet:
# such as a more sweet should but a report the sendsion and sound.
#
# duncant:
# o, he was the grace and scorns do for the graves in the bosom speech that boy, i am as i have sent for the princess, the destreat of his bless that present the man did well at the three that they should be bear the fire the worthy say the beauty with you the moon, and see
# ----------- Epoch 17/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# but fair sight his eyes that thear in the best did patera.
#
# solemban:
# then, i thank the hated the words in the town that gone,
# and make the dance.
#
# rosaline:
# not some morning,
# as my praise the hearted and sole the worse, and with the nestors of the hand, and the presence fashion to the word is a moon in the contrar'd by the moon and that then in the prive here the part the wind of the morning of the boy prove it is not heaven in the english me to make you a read,
# and the sen.
#
# boyet:
# she hath please it with the grace of the moon.
#
# boyet:
# then she bear me to dance on the contented to you see his love in the worse have as a report of the pack is the boy by the word.
#
# dumain:
# you have good of earth, and the world shall be we look to spend the boy be some mother's measure and there is not be, and come to the fathers it do thou art the our sweet an heart, and he that will would look for my beauty banishes, that made the content this fair young one for her lady most thousand men of their beau
# ----------- Epoch 18/60 -----------
# Seed: f.
#
# biron:
# b
# Result: f.
#
# biron:
# be most desire the cannoty office for the word of patient.
#
# ferdinand:
# will you may not to hear them that is my child in the word is like a like one have one of the soul with it were to a screat the breath
# than the tair, the heart for this grace.
#
# biron:
# all man i found the heart of grace, you have in this to the played his boys,
# and confess the time in such as in some that show the manst thou that she is a proclimation the measters, and you have as a true, and the wits and man and say the through the house.
#
# boyet:
# and thou didst thous with the precious stand with as i say he something see the grace and with the enough, thou shouther, the perfery.
#
# princess:
# what some present in the means is a sone words and bear the talk of the break her content than the banishing the tent the eyes are the prince conceral and in the world was a dog for the love here, and thou hast the word is the words we with me with you, and do you do you out
# that do you the love's praise the pleasure in our tailous
# ----------- Epoch 19/60 -----------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-602a55559851> in <module>()
#       2 text = read_data('nietzsche.txt')
#       3 train_data, target_data, unique_chars, len_unique_chars = featurize(text)
# ----> 4 run(train_data, target_data, unique_chars, len_unique_chars)
#
# <ipython-input-6-f85ea9240175> in run(train_data, target_data, unique_chars, len_unique_chars)
#      25             train_batch, target_batch = train_data[count:count+batch_size], target_data[count:count+batch_size]
#      26             count += batch_size
# ---> 27             sess.run([optimizer] ,feed_dict={x:train_batch, y:target_batch})
#      28
#      29         #get on of training set as seed
#
# c:\users\bibows\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# c:\users\bibows\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# c:\users\bibows\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# c:\users\bibows\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# c:\users\bibows\appdata\local\programs\python\python35\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
